# %% [markdown]
# # Neural Nets
# ![syl.jpg](attachment:syl.jpg)

# %% [markdown]
# * 	MATH & STATS & DATA
# # How it is different ?
# *	Traditional Prog(Number Plate recog. – write set of rules to reach outcome) VS
#     Machine Learning( flips it over – given Outcome prog learns how to get there )
# **Example :**
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Other Example :**
# * Playing a game, Compose music, generate painting
# * Curruntly it everywhere amazon, flipkart, Netflix / youtube

# %% [markdown]
# ![ml_map.png](attachment:ml_map.png)
#
# * also no feature engineering req :)

# %% [markdown]
# # Why Neural Nets is hot right now???
# * observed SVM, LR etc.. performance plateau as numb of data increases.
# * Data , Computation (distributed)
# * smaller N.N and larger N.n

# %% [markdown]
# # NN structure
# * When a nerwork is not just 1 or 2 but several layers deep its called deep learning
# * Deep learning model has outperformed every other model, almost evrytime on array of task.
#
#
# ![image.png](attachment:image.png)
# **break through like:**
# * NLP task : sentiment analysis, Q n A,
# * generating new text openAi GPT-2 papaer
# * Resnet paper 152 lauer deep netork is able to classify thousand of images
# * generating rap songs
# * apparantly paper that plays a game better than humans

# %% [markdown]
# #  Lets look @ perceptron
# ![image.png](attachment:image.png)

# %% [markdown]
# # Perceptron model Mathematically
# ![image.png](attachment:image.png)

# %% [markdown]
# # Basic Building Blocks of N.N
#
# **PARAMETER** ( Weights and Bias)
#
# *  W and b, which the model updates during the backpropagation
# *  relation btwn dimensions of w and i (refer diag. abv.)
#
# **Activation Function** #colah blog t,s,t
#
# * activation function plays an important role, helps to learn non - linear curves
# ![act.JPG](attachment:act.JPG)
#
# * Sigmoid : Used in the output layer for binary classification, but Updates parameters slowly when points are at extreme ends
# * Relu : pdates parameters faster as slope is 1 when x>0
#
#
# **Loss Function**
#
# * lError = y pred - y expected

# %% [markdown]
#    ![image.png](attachment:image.png)

# %% [markdown]
# # Feed Forward N.N

# %%
from IPython.display import Image
Image(filename='ff.gif')

# %% [markdown]
# # Mathematically
# ![image.png](attachment:image.png)

# %% [markdown]
# # Different DL framework and cloud services

# %% [markdown]
# # Reducing loss: Gradient Descent
# * Mathematical optimization tecq used reach @ a global minmum where error is small
# * It uses Derivatives
# * Convex problems have only one minimum; that is, only one place where the slope is exactly 0. That minimum is where the loss function converges.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Figure : Regression problems yield convex loss vs weight plots.**
# # when gradient descent is applied to neural networks, its called back-propagation

# %% [markdown]
# # Hyperparameters

# %% [markdown]
# **Learning rate – ⍺**
#
# https://developers.google.com/machine-learning/crash-course/reducing-loss/learning-rate
#
# **Units in each hidden layer**
#
# **Number of hidden layers**
#
#
# **Dropout Regularization**
#
# **Activation Function**
#
# **weight initialization** [ keras links]
#
# **optmizer**
#
# **epoch**

# %% [markdown]
# ![GD.PNG](attachment:GD.PNG)

# %% [markdown]
# **SGD** : one exapmle @ a time
# **Batch GD**

# %% [markdown]
#  * Diffrentiate( derv. )
#  * deep learning pipeline
#  * CNN / RNN

# %% [markdown]
# # Other Deep Neural Architecture
# **CNN**
# ![image.png](attachment:image.png)

# %% [markdown]
# **RNN**
# ![image.png](attachment:image.png)

# %% [markdown]
# **There are even more hyper parameter wrt each of the above N.N architecture.**

# %%
2+2
# Out:
# 4
