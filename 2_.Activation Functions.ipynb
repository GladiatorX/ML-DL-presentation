# %% [markdown]
# # Activation function aka non linearity

# %% [markdown]
# # Linear func
# ![lin.JPG](attachment:lin.JPG)

# %% [markdown]
# # Short coming of linear function
# *  A Neural Network without Activation function would simply be a Linear regression Model
# ![image.png](attachment:image.png)

# %% [markdown]
# # Non linear function
# ![image.png](attachment:image.png)

# %% [markdown]
# # solves
# * adding non linearity helps model more complicated ,high dimensional,non-linear -big datasets
# ![image.png](attachment:image.png)

# %% [markdown]
# # Why non- linear ??
# * it transforms, translate, scales the data so it can be seperable
# * dy/dx of linear is constant
# * linear operation of linear func give linear matrix as o/p (so any layer deep network wont be able to model non linear complexity)
# * learns complex function
# * change in input doesnt change op significantly

# %% [markdown]
# Activation Function	Pros	Cons
# * Sigmoid	Used in the output layer for binary classification	Output ranges from 0 to 1
# * tanh	Better than sigmoid	Updates parameters slowly when points are at extreme ends
# * ReLU	Updates parameters faster as slope is 1 when x>0	Zero slope when x<0

# %% [markdown]
# ![which-activation-relu.jpg](attachment:which-activation-relu.jpg)
