# %% [markdown]
# * Mostly for multi class classification its done one-hot vector encoding
# * Example : MNIST clothing, digit recognition algo (1- 10)
#
# * but if we have millions of class we use embeddings
#
# * softmax used for guessing what probab class likly it belongs, useful in backprop
#
# * cross- entropy loss function for entire training ==> error function(y^ - Y)
#
# # SGD hyper params
# * momentum take running avgs of
# * learning rate decay (to take smaller steps as obj function tries to minimize loss) else it overshoot global minima
# * initial alpha rate
# * learning decay rate
# * momentum
# * batch size
# * weight init
# # lower alpha rate ****
#
# # ADAGRAD friend
#
# # stochastic grad descent
# ![image.png](attachment:image.png)
#
# * one example is selected @ random(k sample of m set picked totally random) **
# * In SGD we consider only one example @ each ieration and compute its gradient rather then suming all m example
# * Though this take random values to minimize cost(sometime even increasing cost function) its compnistaed @ later layer of iterattions that evantually converge
# * cost being more iteration epochs = 10000 which is still computationally inexpensive
# * DRUNK MAN GOING DOWNHILL
#
# # grad descent
#
# ![image.png](attachment:image.png)
#
# * In Grad descent we loop through entier m training example
# * and compute loss w.r.t to each training(m) sample
# * we sum it up entier m samples and compute the derivative
# * and doing it over its very expensive(iterativly)
#
# # mini batch Stochastic grad descent
# *  Mini-batch gradient descent uses n data points (instead of 1 sample in SGD) at each iteration.
#
#
# # cross validation

# %% [markdown]
# # WHY NON LINEAR
# * dy/dx of linear is constant
# * linear operation of linear func give linear matrix as o/p
# * change in input doesnt change op significantly
# * learns complex function

# %% [markdown]
# # Optimization avoid overfitting
# https://www.analyticsvidhya.com/blog/2018/04/fundamentals-deep-learning-regularization-techniques/

# %% [markdown]
# # Regularization intuition
# * stopping to train as soon as it doesnt improve accuracy
# * its a hyperparameer tuning nob
# * adding a term to loss that penalises large weight
#
#
# # L2 Regularisation
# ![image.png](attachment:image.png)
# * L2 regularization is also known as weight decay as it forces the weights to decay towards zero (but not exactly zero).

# %% [markdown]
# # Dropout Intiution
# * capture more randomness hyperparameter no
# * here @ every iteration we randomly drops out neuron in a layer so as to have diffrent set of output
# ![image.png](attachment:image.png)
# * It can also be thought of as an ensemble technique in machine learning.

# %% [markdown]
# # Bias Variance

# %% [markdown]
# * Like ML ther isn't trade of , both are independent
# # Bias
# * Bias = underfitting
# * Doesnt learn data point well
# * ignores training data so there miss classification
# # solution
# * if high bias
#     * increaser N.N
#     * run Grad Desc longer (number of epochs)

# %% [markdown]
# # Variance
# * Overfitting
# * overfits training data
# * doesnt generalize well
#
# # solution
# * if high variance
#     * Regularisation
#     * feed More Data

# %% [markdown]
# # Activation Function
# * sigmoid
# * relu
# * softmax
# * tanh

# %% [markdown]
# # https://www.datacamp.com/courses/natural-language-processing-fundamentals-in-python?tap_a=5644-dce66f&tap_s=210732-9d6bbf
